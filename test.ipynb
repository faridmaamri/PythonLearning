# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ### **TESTS**

# %%
# !pip install urllib
# Out:
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
import re
from urllib.parse import quote,unquote

# %%
s = 'foo123barzquxG'
url ='imgurl=https%3A%2F%2Fwww.biologicaldiversity.org%2Fassets%2Fimg%2Fspecies%2Fmammals%2FGrizzlyBearRobinSilver.jpg&imgrefurl=https%3A%2F%2Fwww.biologicaldiversity.org%2Fspecies%2Fmammals%2Fgrizzly_bear%2F&docid=u2AMRhousssewM&tbnid=NTOTOtbhyxy69M&vet=12ahUKEwjz6uOyyZiTAxWaFlkFHSeZEx8QnPAOegQIGxAB..i&w=570&h=330&hcb=2&ved=2ahUKEwjz6uOyyZiTAxWaFlkFHSeZEx8QnPAOegQIGxAB'
u='<a href="/imgres?q=grizzly%20bear&amp;imgurl=https%3A%2F%2Ftransforms.stlzoo.org%2Fproduction%2Fanimals%2Fgrizzly-bear-01-01.jpg%3Fw%3D1200%26h%3D630%26q%3D82%26auto%3Dformat%26fit%3Dclip%26dm%3D1658944720%26s%3Dda867e45b6f99c4aea90e3c1998b277f&amp;imgrefurl=https%3A%2F%2Fstlzoo.org%2Fanimals%2Fmammals%2Fcarnivores%2Fgrizzly-bear&amp;docid=3OiYcmQC3rL_KM&amp;tbnid=0yjXmZSDZ5b2pM&amp;vet=12ahUKEwjz6uOyyZiTAxWaFlkFHSeZEx8QnPAOegQIGRAB..i&amp;w=630&amp;h=630&amp;hcb=2&amp;ved=2ahUKEwjz6uOyyZiTAxWaFlkFHSeZEx8QnPAOegQIGRAB"><div class="F0uyec" jscontroller="aw2uhd" data-eqld="CgIIABAAOgQIARAAVSJMAz9tEzrcPg" data-preview-id="" data-sv-cpt="4" id="e-0yjXmZSDZ5b2pM" role="button" tabindex="0" jsaction="h5M12e;tErFub:hwpOM;fRiDjd:J29LQb;rcuQ6b:npT2md;mouseover:UI3Kjd;" jsdata="XZxcdf;0yjXmZSDZ5b2pM;d8GxabPTO5qt5NoPp7LO-AE21" data-sve="" data-ved="2ahUKEwjz6uOyyZiTAxWaFlkFHSeZEx8QnPAOegQIGRAB"><div class="H8Rx8c" style="height:180px"><div style="max-height:225px;max-width:225px" class="q1MG4e mNsIhb"><img id="dimg_d8GxabPTO5qt5NoPp7LO-AE_14" src="data:image/jpeg;base64,..." style="object-position:20% 43%" alt="Grizzly Bear | Saint Louis Zoo" class="YQ4gaf" height="225" width="225" data-csiid="d8GxabPTO5qt5NoPp7LO-AE_16" data-atf="1"></div><div class="cC9Rib"></div></div></div></a>'

# %%
html =[u,url]
len(html)
# Out:
# 2

# %%
[re.findall(r'imgurl=(https?[^&]+)',unquote(item)) for item in html]
# Out:
# [['https://transforms.stlzoo.org/production/animals/grizzly-bear-01-01.jpg?w=1200'],
#  ['https://www.biologicaldiversity.org/assets/img/species/mammals/GrizzlyBearRobinSilver.jpg']]

# %% [markdown]
# ## Practice ##
